# %%
import numpy as np
import seaborn as sns

# %%
data_array = np.load("chirpM_tilt.npy")

# %%
np.argsort(data_array[:,0])
# Out:
# array([3027, 4111, 1836, ..., 4423, 3347, 5456])

# %%
data_array[:,1]= data_array[:, 1][np.argsort(data_array[:,0])]

# %%
data_array[:,0].sort()

# %%
import matplotlib.pyplot as plt

# %%
data_array[:,0][-10:]
# Out:
# array([12.35634195, 12.39093687, 12.52582306, 12.55550766, 12.83089855,
#        12.89812963, 12.93335654, 13.65873135, 13.97185012, 14.10879558])

# %%
data_array[:,1]
# Out:
# array([ 57.72858437,  95.19566554,  98.88644298, ...,  45.78170325,
#         33.07289262, 165.48408863])

# %%
ax = sns.lineplot(x=np.around(data_array[:,0]), y=data_array[:,1])

# %%
ax = sns.histplot(x=np.around(data_array[:,0]))
